# %%
import cv2

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
# read image
image=cv2.imread("dog.jpg",1)
# 1 means in same color channel --RGB
# 0 means no color channel --Black & white ---Grey image
# -1 maintain image transparency ---

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (177, 285, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
# cv2.imshow() does not work on colab because colab has not feature to access system camera
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=285x177 at 0x7FC48D40D550>

# %%
img=cv2.imread("dog.jpg",0)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=285x177 at 0x7FC48D4D4898>

# %%
cv2_imshow(image[50:,50:180])
# Out:
# <PIL.Image.Image image mode=RGB size=130x127 at 0x7FC489319630>

# %%
x,y,z=cv2.split(image)

# it split color 
# since cv support BGR format so
# x-----Blue
# y-----Green
# z-----Red

# %%
x
# Out:
# array([[17, 18, 18, ..., 26, 28, 31],
#        [22, 22, 22, ..., 25, 27, 31],
#        [26, 26, 26, ..., 25, 27, 28],
#        ...,
#        [15,  3,  5, ..., 30, 35, 22],
#        [22, 16, 18, ..., 20, 27, 20],
#        [26, 29, 20, ..., 27, 36, 26]], dtype=uint8)

# %%
cv2_imshow(x)
# Out:
# <PIL.Image.Image image mode=L size=285x177 at 0x7FC4893194A8>

# %%
cv2_imshow(y)
# Out:
# <PIL.Image.Image image mode=L size=285x177 at 0x7FC4893197F0>

# %%
cv2_imshow(z)
# Out:
# <PIL.Image.Image image mode=L size=285x177 at 0x7FC489319898>

# %%
plt.imshow(x)

# %%
plt.imshow(y)

# %%
plt.imshow(z)

# %%
# to draw a line in image
x=cv2.line(image,(0,0),(200,330),(0,0,255),3)

# %%
cv2_imshow(x)
# Out:
# <PIL.Image.Image image mode=RGB size=285x177 at 0x7FC489319710>

# %%
cv2_imshow(cv2.rectangle(image,(50,50),(150,150),(0,255,0),3))        # draw a rectangle
# Out:
# <PIL.Image.Image image mode=RGB size=285x177 at 0x7FC48922A588>

# %%
cv2_imshow(cv2.rectangle(image,(50,50),(100,100),(0,255,0),-1))
# Out:
# <PIL.Image.Image image mode=RGB size=285x177 at 0x7FC48924C438>
