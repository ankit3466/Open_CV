# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
img = cv2.imread('pokemon.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FC3BDA8F860>

# %%
boundaries = [
	([17, 15, 100], [50, 56, 200]),
	([86, 31, 4], [220, 88, 50]),
	([25, 146, 190], [62, 174, 250]),
	([103, 86, 65], [145, 133, 128])
]

# %%
# loop over the boundaries
for (lower, upper) in boundaries:
	# create NumPy arrays from the boundaries
	lower = np.array(lower, dtype = "uint8")
	upper = np.array(upper, dtype = "uint8")
 
  # find the colors within the specified boundaries and apply
	# the mask
	mask = cv2.inRange(img, lower, upper)
	output = cv2.bitwise_and(img, img, mask = mask)
 
	#show the images
	cv2_imshow(np.hstack([img, output]))
	#cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7FC3BD135B00>
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7FC3BD135B38>
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7FC3BD135BA8>
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7FC3BD135B70>
