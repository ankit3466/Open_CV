# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread('dog.jpg')   # loading image in colored format
img2=cv2.imread('dog.jpg',0)  # for black and white

# %%
img.shape
# Out:
# (177, 285, 3)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=285x177 at 0x7F8AC521C4A8>

# %%
x=img-50

# %%
cv2_imshow(x)
# Out:
# <PIL.Image.Image image mode=RGB size=285x177 at 0x7F8AC51A7400>

# %%
cv2_imshow(img-100)
# Out:
# <PIL.Image.Image image mode=RGB size=285x177 at 0x7F8AC51A76D8>

# %%
cv2_imshow(img+200)
# Out:
# <PIL.Image.Image image mode=RGB size=285x177 at 0x7F8AC51A7588>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=285x177 at 0x7F8AC51A7588>

# %%
cv2_imshow(img2/5)
# Out:
# <PIL.Image.Image image mode=L size=285x177 at 0x7F8AC51A75C0>

# %%
cv2_imshow(img2*1.5)
# Out:
# <PIL.Image.Image image mode=L size=285x177 at 0x7F8AC51A7748>

# %%
# for saving pic
cv2.imwrite('newdog.jpg',img2)
# Out:
# True

# %%
y=cv2.imread('newdog.jpg')

# %%
cv2_imshow(y)
# Out:
# <PIL.Image.Image image mode=RGB size=285x177 at 0x7F8AC521C8D0>
